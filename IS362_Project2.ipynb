# %% [markdown]
# # Project 2

# %%
import pandas as pd

# %% [markdown]
# **First Dataset (relinc.csv)
#
# This first dataset is a correlation of yearly salary and religious denomination. The original dataset is untidy because it uses salary values as column headers instead of a variable header, which should be income.  Using melt, this dataset can be organized into a more concise layout.

# %%
df = pd.read_csv('/Users/jamesweatherbee/Desktop/School/IS362_DataAquisition/relinc.csv')
df
# Out:
#    Unnamed: 0  religion  <10k  10-20k  20-30k  30-40k  40-50k  50-75k  \
# 0           0  Agnostic    27      34      60      81      76     137
# 1           1   Atheist    12      27      37      52      35      70
# 2           2  Buddhist    27      21      30      34      33      58
# 3           3  Catholic  4418     617     732     670     638    1116
# 4           4   refused    15      14      15      11      10      35
#
#    75-100k  100-150k  >150k  refused
# 0      122       109     84       96
# 1       73        59     74       76
# 2       62        39     53       54
# 3      949       792    633     1489
# 4       21        17     18      116

# %%
df = df.melt(id_vars=['religion'], var_name=['income'], value_name='frequency')
df
# Out:
#     religion      income  frequency
# 0   Agnostic  Unnamed: 0          0
# 1    Atheist  Unnamed: 0          1
# 2   Buddhist  Unnamed: 0          2
# 3   Catholic  Unnamed: 0          3
# 4    refused  Unnamed: 0          4
# 5   Agnostic        <10k         27
# 6    Atheist        <10k         12
# 7   Buddhist        <10k         27
# 8   Catholic        <10k       4418
# 9    refused        <10k         15
# 10  Agnostic      10-20k         34
# 11   Atheist      10-20k         27
# 12  Buddhist      10-20k         21
# 13  Catholic      10-20k        617
# 14   refused      10-20k         14
# 15  Agnostic      20-30k         60
# 16   Atheist      20-30k         37
# 17  Buddhist      20-30k         30
# 18  Catholic      20-30k        732
# 19   refused      20-30k         15
# 20  Agnostic      30-40k         81
# 21   Atheist      30-40k         52
# 22  Buddhist      30-40k         34
# 23  Catholic      30-40k        670
# 24   refused      30-40k         11
# ...

# %% [markdown]
# **Second dataset
